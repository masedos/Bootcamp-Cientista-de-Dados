# %% [markdown]
# **Verificando se os arquivos estão nas pastas indicadas**

# %%
# %fs ls /FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv</td><td>Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv</td><td>463094961</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_01-24d0c.json</td><td>d1995_07_01-24d0c.json</td><td>7451741</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_02-c3f44.json</td><td>d1995_07_02-c3f44.json</td><td>9572086</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_03-f99af.json</td><td>d1995_07_03-f99af.json</td><td>14125303</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_04-c5a7f.json</td><td>d1995_07_04-c5a7f.json</td><td>12030333</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_05-0f261.json</td><td>d1995_07_05-0f261.json</td><td>14662194</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_06-20619.json</td><td>d1995_07_06-20619.json</td><td>15557682</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_07-2dd8d.json</td><td>d1995_07_07-2dd8d.json</td><td>15279295</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_08-83302.json</td><td>d1995_07_08-83302.json</td><td>7033852</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_09-f75d3.json</td><td>d1995_07_09-f75d3.json</td><td>5589076</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_10-160a3.json</td><td>d1995_07_10-160a3.json</td><td>10616482</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_11-8800f.json</td><td>d1995_07_11-8800f.json</td><td>12486245</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_12-3091c.json</td><td>d1995_07_12-3091c.json</td><td>14080494</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_13-242b2.json</td><td>d1995_07_13-242b2.json</td><td>21989188</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_14-bab67.json</td><td>d1995_07_14-bab67.json</td><td>13780636</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_15-57e08.json</td><td>d1995_07_15-57e08.json</td><td>8057272</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_16-2ca03.json</td><td>d1995_07_16-2ca03.json</td><td>7171848</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_17-905a5.json</td><td>d1995_07_17-905a5.json</td><td>11897536</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_18-13b8b.json</td><td>d1995_07_18-13b8b.json</td><td>10569098</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_19-e2537.json</td><td>d1995_07_19-e2537.json</td><td>11515206</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_20-0f6d2.json</td><td>d1995_07_20-0f6d2.json</td><td>11049142</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_21-37a88.json</td><td>d1995_07_21-37a88.json</td><td>10475868</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_22-3b894.json</td><td>d1995_07_22-3b894.json</td><td>6028420</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_23-8d606.json</td><td>d1995_07_23-8d606.json</td><td>5620028</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_24-bcae5.json</td><td>d1995_07_24-bcae5.json</td><td>10433367</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_25-22c14.json</td><td>d1995_07_25-22c14.json</td><td>9883055</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_26-8a504.json</td><td>d1995_07_26-8a504.json</td><td>9087395</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_27-32f69.json</td><td>d1995_07_27-32f69.json</td><td>10172162</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_28-8d6d2.json</td><td>d1995_07_28-8d6d2.json</td><td>6206927</td></tr><tr><td>dbfs:/FileStore/tables/designation.json</td><td>designation.json</td><td>400</td></tr><tr><td>dbfs:/FileStore/tables/iris_bezdekIris.csv</td><td>iris_bezdekIris.csv</td><td>4551</td></tr><tr><td>dbfs:/FileStore/tables/kddcup_data_10_percent_corrected-2f6f3</td><td>kddcup_data_10_percent_corrected-2f6f3</td><td>74889749</td></tr><tr><td>dbfs:/FileStore/tables/regressaoLinear.csv</td><td>regressaoLinear.csv</td><td>564</td></tr><tr><td>dbfs:/FileStore/tables/salario_df.csv</td><td>salario_df.csv</td><td>2505</td></t ...

# %% [markdown]
# ** Criando o diretório de saída**

# %%
#define o caminho para a saida
output_path = "/tmp/pydata/Streaming/output/"
dbutils.fs.rm(output_path,True)
dbutils.fs.mkdirs(output_path)

#define o caminho para o checkpoint, necessário para utilizar algumas funçoes e garantir tolerância a falhas
checkpoint_path = "/tmp/pydata/Streaming/checkpoint/"
dbutils.fs.rm(checkpoint_path,True)
dbutils.fs.mkdirs(checkpoint_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>

# %% [markdown]
# **Definindo o esquema para o dataset**

# %%
from pyspark.sql.types import StructType,IntegerType,StringType,LongType,StructField,TimestampType
schema_entrada =  StructType([
    StructField("bytes", LongType()),
    StructField("host", StringType()),
    StructField("http_reply", IntegerType()),
    StructField("request", StringType()),
    StructField("timestamp", StringType())
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Criando o dataframe estático

# %%
logsDirectoryStatic= "/FileStore/tables/d1995_07_01-24d0c.json" #define o local onde os arquivos estão armazenados
static=spark.read.json(logsDirectoryStatic,schema_entrada)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Verificando se o dataframe é estático ou streaming

# %%
static.isStreaming
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: False</div>

# %%
#print do schema
static.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- bytes: long (nullable = true)
# -- host: string (nullable = true)
# -- http_reply: integer (nullable = true)
# -- request: string (nullable = true)
# -- timestamp: string (nullable = true)
#
# </div>

# %% [markdown]
# **Conhecendo o banco de dados**

# %%
#apresenta as primeiras 5 linhas do dataframe
static.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------------------+----------+--------------------+--------------------+
# bytes|                host|http_reply|             request|           timestamp|
# +-----+--------------------+----------+--------------------+--------------------+
#  6245|        199.72.81.55|       200|GET /history/apol...|1995-07-01T06:00:...|
#  3985|unicomp6.unicomp.net|       200|GET /shuttle/coun...|1995-07-01T06:00:...|
#  4085|      199.120.110.21|       200|GET /shuttle/miss...|1995-07-01T06:00:...|
#     0|  burger.letters.com|       304|GET /shuttle/coun...|1995-07-01T06:00:...|
#  4179|      199.120.110.21|       200|GET /shuttle/miss...|1995-07-01T06:00:...|
# +-----+--------------------+----------+--------------------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
#contando a quantidade de linhas existente no dataframe
(static.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 45657</div>

# %%
#retorna o valor médio de bytes gerados pelas consultas
from pyspark.sql.functions import avg
static.select(avg("bytes")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
#        avg(bytes)|
# +-----------------+
# 25213.30665615349|
# +-----------------+
#
# </div>

# %%
#seleciona a quantidade de valores diferentes existentes na coluna host
from pyspark.sql.functions import asc, col, desc

grupo_host_distintos=static.select("host").distinct().sort(col("host").asc())
grupo_host_distintos.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------+
#            host|
# +---------------+
#  128.102.86.254|
#  128.138.177.51|
#  128.147.44.103|
#   128.148.15.20|
#  128.158.21.103|
#  128.158.54.114|
# 128.159.122.119|
#  128.159.132.53|
# 128.159.154.142|
#   128.163.80.98|
# 128.171.118.102|
# 128.187.140.171|
#  128.194.252.50|
#  128.220.40.121|
#  128.220.56.135|
#  128.250.245.53|
# 128.252.230.210|
#   128.253.21.23|
#   128.59.161.66|
#   128.95.200.71|
# +---------------+
# only showing top 20 rows
#
# </div>

# %%
#cria a tabela para utilizar a consulta via SQL
static.createOrReplaceTempView("grupo_1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT DISTINCT host
  FROM grupo_1
ORDER BY host
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host</th></tr></thead><tbody><tr><td>128.102.86.254</td></tr><tr><td>128.138.177.51</td></tr><tr><td>128.147.44.103</td></tr><tr><td>128.148.15.20</td></tr><tr><td>128.158.21.103</td></tr><tr><td>128.158.54.114</td></tr><tr><td>128.159.122.119</td></tr><tr><td>128.159.132.53</td></tr><tr><td>128.159.154.142</td></tr><tr><td>128.163.80.98</td></tr><tr><td>128.171.118.102</td></tr><tr><td>128.187.140.171</td></tr><tr><td>128.194.252.50</td></tr><tr><td>128.220.40.121</td></tr><tr><td>128.220.56.135</td></tr><tr><td>128.250.245.53</td></tr><tr><td>128.252.230.210</td></tr><tr><td>128.253.21.23</td></tr><tr><td>128.59.161.66</td></tr><tr><td>128.95.200.71</td></tr><tr><td>129.102
</td></tr><tr><td>147.151.16.204</td></tr><tr><td>147.31.254.131</td></tr><tr><td>147.35.241.3</td></tr><tr><td>148.202.3.244</td></tr><tr><td>148.202.9.5</td></tr><tr><td>148.207.36.23</td></tr><tr><td>148.216.5.20</td></tr><tr><td>148.225.80.35</td></tr><tr><td>148.241.10.249</td></tr><tr><td>149.123.74.30</td></tr><tr><td>149.171.160 ...

# %% [markdown]
# **Criando o modelo dinâmico (Streaming)**

# %%
#importando bibliotecas
from pyspark.sql.functions import input_file_name,current_timestamp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#define o caminho para a entrada dos arquivos de log
logsDirectoryStreaming= "/FileStore/tables/*.json" #define o local onde os arquivos estão armazenados
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Definindo o modelo de Streaming
streamingDF = ( spark 
          .readStream 
          .schema(schema_entrada) #esquema definido para a coleta dos dados presentes em JSON
          .option("maxFilesPerTrigger", 1)  #mantém a leitura de apenas um arquivo por batch, para manter mais lenta a coleta
          .json(logsDirectoryStreaming) #define o local a ser pesquisado para obter os dados
          .withColumn("INPUT_FILE_NAME", input_file_name()) #cria a coluna para armazenar o nome do arquivo o qual o dado foi lido
          .withColumn("PROCESSED_TIME", current_timestamp()) #adiciona o tempo em que o dado foi processado
          .withWatermark("PROCESSED_TIME", "1 minute") #adiciona a janela de tempo para a leitura (marca d'água)
         )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# define a saída (sink)
query = (streamingDF
         .writeStream
         .format("parquet") #define o formato do arquivo a ser utilizado (parquet)
         .option("path", output_path) #define o local onde os arquivos devem ser adicionados
         .option("checkpointLocation", checkpoint_path) # define o checkpoint para garantir a tolerãncia a falhas
         .outputMode("append") # define o modo de saída para os dados
         .queryName("logs") #define o nome para a consulta
         .trigger(processingTime='5 seconds') #define o "tempo de processamento" para cada dado recebido
         .start() #inicia o processamento em streaming
        )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Visualizando as Saídas em Tempo Real**

# %%
#cria a tabela para realizar as consultas sobre os dados que estãos sendo lidos
streamingDF.createOrReplaceTempView("logs_table_in")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select COUNT(*) from logs_table_in where http_reply = 200
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1701451</td></tr></tbody></table></div>

# %% [markdown]
# **Realizando a leitura dos dados na pasta de saída**

# %%
#define o esquema para a leitura dos dados que estão na pasta de saída
#esquema modificado para que os dados possam ser adicionados ao formato de saída
schemaSaida = (
  StructType()
  .add("timestamp", TimestampType()) #event time 
  .add("bytes", LongType())
  .add("host", StringType())
  .add("http_reply", IntegerType())
  .add("request", StringType())
  .add("INPUT_FILE_NAME", StringType()) #Nome do arquivo em que o dado do sensor foi criado 
  .add("PROCESSED_TIME", TimestampType())) #timestamp para o processamento dos dados
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.conf.set("spark.sql.shuffle.partitions", "1") #define valor para os shuffles

#define a configuração para a leitura
saidasLogs = (spark.readStream
           .schema(schemaSaida) #lê os dados através do esquema definido para a transformação
           .format("parquet") #define o formato dos aquivos de leitura
           .option("maxFilesPerTrigger", 1) #Mantém a leitura dos dados como 1 arquivo para a demonstração ser mais lenta
           .load(output_path) # indica de onde o arquivo será lido 
           .withWatermark("PROCESSED_TIME", "1 minute") #define a janela de tempo para a leitura dos dados
          )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# define a tabela temporária para que seja possível realizar as consultas sobre os dados utilizando o SQL 
saidasLogs.createOrReplaceTempView("logs_table_out")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select COUNT(*) from logs_table_out
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1872014</td></tr></tbody></table></div>

# %% [markdown]
# Valor médio para cada host

# %%
# %sql
SELECT host, AVG(bytes) as media FROM logs_table_out GROUP BY host
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
enet.net</td><td>11571.25</td></tr><tr><td>167.91.2.148</td><td>13202.5</td></tr><tr><td>kbolvin.qualcomm.com</td><td>6603.961538461538</td></tr><tr><td>fr-914.cc.iastate.edu</td><td>82275.08333333333</td></tr><tr><td>dialin-ttype.sky.net</td><td>3728.809523809524</td></tr><tr><td>204.187.145.202</td><td>17319.0</td></tr><tr><td>ix-nhv-ct1-10.ix.netcom.com</td><td>2497.5</td></tr><tr><td>pm2161.harajuku.egg.or.jp</td><td>17874.846153846152</td></tr><tr><td>mryan.times.net</td><td>363.0</td></tr><tr><td>cnynppp3.epix.net</td><td>27071.090909090908</td></tr><tr><td>slip35-14.il.us.ibm.net</td><td>2497.5</td></tr><tr><td>202.12.90.212</td><td>5136.8421052631575</td></tr><tr><td>philly17.voicenet.com</td><td>13637.857142857143</td></tr><tr><td>pc02.unseld.co.at</td><td>10753.818181818182</td></tr><tr><td>port19.den1-annex.usa.net</td><td>1720.0</td></tr><tr><td>tsa-27.ucsc.edu</td><td>44620.666666666664</td></tr><tr><td>cad117.cadvision.com</td><td>7058.890909090909</td></tr><tr><td>mac6100-240.mills.edu</td><td>5924.7692307692305< ...

# %% [markdown]
# Linhas com o campo "request" diferentes.

# %%
# %sql 
SELECT DISTINCT request FROM logs_table_out GROUP BY request
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>request</th></tr></thead><tbody><tr><td>GET /htbin/wais.pl?KSC-11582 HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-71/images/KSC-95EC-0916.jpg</td></tr><tr><td>GET /htbin/wais.pl?LviewPro.* HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?LIDAR HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?107,111 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?13,18 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?MAS HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/fr?43,43?19,457 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?289,285 HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-48/images/91HC616.GIF HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?55,219 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?Jack+Swigert HTTP/1.0</td></tr><tr><td>GET /statistics/1993/Dec/Dec93_request.gif HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/astrohome?273,299 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?75,255 HTTP/1.0</td></tr><tr><td>GET /news/sci.space.news/872 HTTP/1.0</td></tr><tr><td>GET /biomed/history/history.html HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-70/images/KSC-95EC-1000.jpg HTTP/1.0</td></tr><tr><td>GET /history/apollo/as-203/ HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-61/movies/ HTTP/1.0</td></tr><tr><td>GET /htbin/imagemap/Jul95stats_r?82,122 HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-45/sts-45-press-kit.txt HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?72,157 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?68,196 HTTP/1.0</td></tr><tr><td>GET /facilities/vpf.html HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?2+line HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?112,294 HTTP/1.0</td></tr><tr><td>GET /persons/astronauts/m-to-p/MullaneRM.txt HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?297,210 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?flight+deck HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?390,289 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?281,275 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?E-mail+addresses HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?281,292 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?58,222 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?92,137 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?297,285 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?388,278 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?68,162 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?342,162 HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-70/woodpecker.html   HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/astrohome?272,285 HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-34/sounds/ HTTP/1.0</td></tr><tr><td>GET /elv/TITAN/vidpicp.htm HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?52,256 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?aluminium+oxide HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/fr?199,40 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/fr?43,43 HTTP/1.0</td></tr><tr><td>GET /history/gemini/gemini-xii/gemini-xii-info.html HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown70?124,288 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?396,273 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?320,268 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/hq?226,28 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?harris+telecommunicationscorporation HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?376,272 HTTP/1.0</td></tr><tr><td>GET /history/apollo/as-202/news/ HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-26/sts-26-press-kit.txt HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?Galileo%2FIda HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?528,228 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?realtime HTTP/1.0< ...
